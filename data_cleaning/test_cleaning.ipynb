# %%
import pandas as pd

# %%
csv_file = '../Resources/test.csv'
csv_file
# Out:
# '../Resources/test.csv'

# %%
test_df = pd.read_csv(csv_file)
test_df.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
test_df = test_df.loc[(test_df["MSZoning"]=="FV") | (test_df["MSZoning"]=="RH") | (test_df["MSZoning"]=="RL") | (test_df["MSZoning"]=="RP") | (test_df["MSZoning"]=="RM")]

# %%
# get dummies
# MSZoning_dummies = pd.get_dummies(train_df.MSZoning, prefix='MSZoning').iloc[:, 1:]
# MSZoning_dummies.head()

# %%
for col in test_df.columns:
    print(col)
# Out:
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# ...

# %%
# Passing dataframe in to Get dummies for non hierarchical variables 
test_df = pd.get_dummies(test_df, columns=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2','BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'PavedDrive', 'MiscFeature', 'SaleType', 'SaleCondition'], drop_first=True) 
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea ExterQual  ... SaleType_ConLI  \
# 0       1961          1961         0.0        TA  ...              0
# 1       1958          1958       108.0        TA  ...              0
# 2       1997          1998         0.0        TA  ...              0
# 3       1998          1998        20.0        TA  ...              0
# 4       1992          1992         0.0        Gd  ...              0
#
#   SaleType_ConLw SaleType_New SaleType_Oth SaleType_WD  SaleCondition_AdjLand  \
# ...

# %%
test_df.LotFrontage.fillna(0, inplace=True)

# %%
test_df[test_df.LotFrontage.isnull()]
# Out:
# Empty DataFrame
# ...

# %%
test_df["GarageYrBlt"].mean()
# Out:
# 1978.0868613138687

# %%
test_df.GarageYrBlt.fillna(1978, inplace=True)

# %% [markdown]
# # Hirachial variables
# ExterQual
# ExterCond
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# HeatingQC
# KitchenQual
# Functional
# FireplaceQu
# GarageFinish
# GarageQual
# GarageCond
# Fence

# %%
test_df.value_counts('ExterQual')
# Out:
# ExterQual
# TA    879
# Gd    490
# Ex     55
# Fa     16
# dtype: int64

# %%
test_df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1440 entries, 0 to 1458
# Data columns (total 186 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     1440 non-null   int64
#  1   MSSubClass             1440 non-null   int64
#  2   LotFrontage            1440 non-null   float64
#  3   LotArea                1440 non-null   int64
#  4   OverallQual            1440 non-null   int64
#  5   OverallCond            1440 non-null   int64
#  6   YearBuilt              1440 non-null   int64
#  7   YearRemodAdd           1440 non-null   int64
#  8   MasVnrArea             1425 non-null   float64
#  9   ExterQual              1440 non-null   object
#  10  ExterCond              1440 non-null   object
#  11  BsmtQual               1402 non-null   object
#  12  BsmtCond               1399 non-null   object
#  13  BsmtExposure           1400 non-null   object
# ...

# %%
test_df.isnull().sum()
# Out:
# Id                       0
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
#                         ..
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# SaleCondition_Normal     0
# SaleCondition_Partial    0
# Length: 186, dtype: int64

# %%
test_df.ExterQual.value_counts(dropna=False)
# Out:
# TA    879
# Gd    490
# Ex     55
# Fa     16
# Name: ExterQual, dtype: int64

# %%
test_df.ExterQual.fillna(0, inplace=True)

# %%
# formatting  ['ExterQual'] to Hirachial value 
test_df['ExterQual'] = test_df['ExterQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ... SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...              0
# 1       1958          1958       108.0          3  ...              0
# 2       1997          1998         0.0          3  ...              0
# 3       1998          1998        20.0          3  ...              0
# 4       1992          1992         0.0          4  ...              0
#
#   SaleType_ConLw SaleType_New SaleType_Oth SaleType_WD  SaleCondition_AdjLand  \
# ...

# %%
# replace testing 
test_df.value_counts('ExterQual')
# Out:
# ExterQual
# 3    879
# 4    490
# 5     55
# 2     16
# dtype: int64

# %%
test_df.ExterCond.value_counts(dropna=False)
# Out:
# TA    1245
# Gd     152
# Fa      33
# Ex       9
# Po       1
# Name: ExterCond, dtype: int64

# %%
test_df.ExterCond.fillna(0, inplace=True)

# %%
# formatting  ['ExterCond'] to Hirachial value 
test_df['ExterCond'] = test_df['ExterCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#   SaleType_ConLw SaleType_New SaleType_Oth SaleType_WD  SaleCondition_AdjLand  \
# ...

# %%
# replace testing 
test_df.value_counts('ExterCond')
# Out:
# ExterCond
# 3    1245
# 4     152
# 2      33
# 5       9
# 1       1
# dtype: int64

# %%
test_df.BsmtQual.value_counts(dropna=False)
# Out:
# TA     624
# Gd     591
# Ex     137
# Fa      50
# NaN     38
# Name: BsmtQual, dtype: int64

# %%
test_df.BsmtQual.fillna(0, inplace=True)

# %%
test_df.BsmtQual.value_counts()
# Out:
# TA    624
# Gd    591
# Ex    137
# Fa     50
# 0      38
# Name: BsmtQual, dtype: int64

# %%
# test_df.loc[train_df.BsmtQual.isnull()]['BsmtQual']

# %%
# formatting  ['BsmtQual'] to Hirachial value 
test_df['BsmtQual'] = test_df['BsmtQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw SaleType_New SaleType_Oth SaleType_WD  \
# 0               0            0            0           1
# ...

# %%
# replace testing 
test_df.value_counts('BsmtQual')
# Out:
# BsmtQual
# 3    624
# 4    591
# 5    137
# 2     50
# 0     38
# dtype: int64

# %%
test_df.BsmtCond.value_counts(dropna=False)
# Out:
# TA     1284
# Gd       57
# Fa       55
# NaN      41
# Po        3
# Name: BsmtCond, dtype: int64

# %%
test_df.BsmtCond.fillna(0, inplace=True)

# %%
#train_df.loc[train_df.BsmtCond.isnull()]['BsmtCond']

# %%
# formatting  ['BsmtCond'] to Hirachial value 
test_df['BsmtCond'] = test_df['BsmtCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New SaleType_Oth SaleType_WD  \
# 0               0             0            0           1
# ...

# %%
# replace testing 
test_df.value_counts('BsmtCond')
# Out:
# BsmtCond
# 3    1284
# 4      57
# 2      55
# 0      41
# 1       3
# dtype: int64

# %%
test_df.BsmtExposure.value_counts(dropna=False)
# Out:
# No     938
# Av     197
# Gd     142
# Mn     123
# NaN     40
# Name: BsmtExposure, dtype: int64

# %%
test_df.BsmtExposure.fillna(0, inplace=True)

# %%
# formatting  ['BsmtExposure'] to Hirachial value 
test_df['BsmtExposure'] = test_df['BsmtExposure'].replace({'Gd': 4, 'Av': 3, 'Mn': 2, 'No': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth SaleType_WD  \
# 0               0             0             0           1
# ...

# %%
# replace testing 
test_df.value_counts('BsmtExposure')
# Out:
# BsmtExposure
# 1    938
# 3    197
# 4    142
# 2    123
# 0     40
# dtype: int64

# %%
test_df.BsmtFinType1.value_counts(dropna=False)
# Out:
# GLQ    430
# Unf    409
# ALQ    208
# Rec    154
# BLQ    121
# LwQ     80
# NaN     38
# Name: BsmtFinType1, dtype: int64

# %%
test_df.BsmtFinType1.fillna(0, inplace=True)

# %%
# formatting  ['BsmtFinType1'] to Hirachial value 
test_df['BsmtFinType1'] = test_df['BsmtFinType1'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('BsmtFinType1')
# Out:
# BsmtFinType1
# 6    430
# 1    409
# 5    208
# 3    154
# 4    121
# 2     80
# 0     38
# dtype: int64

# %%
test_df.BsmtFinType2.value_counts(dropna=False)
# Out:
# Unf    1222
# Rec      51
# LwQ      41
# NaN      38
# BLQ      35
# ALQ      33
# GLQ      20
# Name: BsmtFinType2, dtype: int64

# %%
test_df.BsmtFinType2.fillna(0, inplace=True)

# %%
# formatting  ['BsmtFinType2'] to Hirachial value 
test_df['BsmtFinType2'] = test_df['BsmtFinType2'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('BsmtFinType2')
# Out:
# BsmtFinType2
# 1    1222
# 3      51
# 2      41
# 0      38
# 4      35
# 5      33
# 6      20
# dtype: int64

# %%
test_df.HeatingQC.value_counts(dropna=False)
# Out:
# Ex    747
# TA    422
# Gd    231
# Fa     39
# Po      1
# Name: HeatingQC, dtype: int64

# %%
test_df.HeatingQC.fillna(0, inplace=True)

# %%
# formatting  ['HeatingQC'] to Hirachial value 
test_df['HeatingQC'] = test_df['HeatingQC'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('HeatingQC')
# Out:
# HeatingQC
# 5    747
# 3    422
# 4    231
# 2     39
# 1      1
# dtype: int64

# %%
test_df.KitchenQual.value_counts(dropna=False)
# Out:
# TA     742
# Gd     564
# Ex     105
# Fa      28
# NaN      1
# Name: KitchenQual, dtype: int64

# %%
test_df.KitchenQual.fillna(0, inplace=True)

# %%
# formatting  ['KitchenQual'] to Hirachial value 
test_df['KitchenQual'] = test_df['KitchenQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('KitchenQual')
# Out:
# KitchenQual
# 3    742
# 4    564
# 5    105
# 2     28
# 0      1
# dtype: int64

# %%
test_df.Functional.value_counts(dropna=False)
# Out:
# Typ     1345
# Min2      34
# Min1      33
# Mod       18
# Maj2       4
# Maj1       4
# Sev        1
# NaN        1
# Name: Functional, dtype: int64

# %%
test_df.Functional.fillna(0, inplace=True)

# %%
# formatting  ['Functional'] to Hirachial value 
test_df['Functional'] = test_df['Functional'].replace({'Typ': 8, 'Min1': 7, 'Min2': 6, 'Mod': 5, 'Maj1': 4, 'Maj2': 3 , 'Sev': 2, 'Sal': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('Functional')
# Out:
# Functional
# 8    1345
# 6      34
# 7      33
# 5      18
# 4       4
# 3       4
# 2       1
# 0       1
# dtype: int64

# %%
test_df.FireplaceQu.value_counts(dropna=False)
# Out:
# NaN    712
# Gd     363
# TA     279
# Fa      41
# Po      26
# Ex      19
# Name: FireplaceQu, dtype: int64

# %%
test_df.FireplaceQu.fillna(0, inplace=True)

# %%
# formatting  ['FireplaceQu'] to Hirachial value 
test_df['FireplaceQu'] = test_df['FireplaceQu'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('FireplaceQu')
# Out:
# FireplaceQu
# 0    712
# 4    363
# 3    279
# 2     41
# 1     26
# 5     19
# dtype: int64

# %%
test_df.GarageFinish.value_counts(dropna=False)
# Out:
# Unf    615
# RFn    388
# Fin    367
# NaN     70
# Name: GarageFinish, dtype: int64

# %%
test_df.GarageFinish.fillna(0, inplace=True)

# %%
# formatting  ['GarageFinish'] to Hirachial value 
test_df['GarageFinish'] = test_df['GarageFinish'].replace({'Fin': 3, 'RFn': 2, 'Unf': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('GarageFinish')
# Out:
# GarageFinish
# 1    615
# 2    388
# 3    367
# 0     70
# dtype: int64

# %%
test_df.GarageQual.value_counts(dropna=False)
# Out:
# TA     1287
# Fa       72
# NaN      70
# Gd       10
# Po        1
# Name: GarageQual, dtype: int64

# %%
test_df.GarageQual.fillna(0, inplace=True)

# %%
# formatting  ['GarageQual'] to Hirachial value 
test_df['GarageQual'] = test_df['GarageQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('GarageQual')
# Out:
# GarageQual
# 3    1287
# 2      72
# 0      70
# 4      10
# 1       1
# dtype: int64

# %%
test_df.GarageCond.value_counts(dropna=False)
# Out:
# TA     1322
# NaN      70
# Fa       36
# Gd        6
# Po        5
# Ex        1
# Name: GarageCond, dtype: int64

# %%
test_df.GarageCond.fillna(0, inplace=True)

# %%
# formatting  ['GarageCond'] to Hirachial value 
test_df['GarageCond'] = test_df['GarageCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN': 0})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('GarageCond')
# Out:
# GarageCond
# 3    1322
# 0      70
# 2      36
# 4       6
# 1       5
# 5       1
# dtype: int64

# %%
test_df.PoolQC.value_counts(dropna=False)
# Out:
# NaN    1437
# Ex        2
# Gd        1
# Name: PoolQC, dtype: int64

# %%
test_df.PoolQC.fillna(0, inplace=True)

# %%
# formatting  ['PoolQC'] to Hirachial value 
test_df['PoolQC'] = test_df['PoolQC'].replace({'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'NaN': 0})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('PoolQC')
# Out:
# PoolQC
# 0    1437
# 4       2
# 3       1
# dtype: int64

# %%
test_df.Fence.value_counts(dropna=False)
# Out:
# NaN      1150
# MnPrv     172
# GdPrv      59
# GdWo       58
# MnWw        1
# Name: Fence, dtype: int64

# %%
test_df.Fence.fillna(0, inplace=True)

# %%
# formatting  ['Fence'] to Hirachial value 
test_df['Fence'] = test_df['Fence'].replace({'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1})
test_df.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0  1461          20         80.0    11622            5            6
# 1  1462          20         81.0    14267            6            6
# 2  1463          60         74.0    13830            5            5
# 3  1464          60         78.0     9978            6            6
# 4  1465         120         43.0     5005            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  \
# 0       1961          1961         0.0          3  ...               0
# 1       1958          1958       108.0          3  ...               0
# 2       1997          1998         0.0          3  ...               0
# 3       1998          1998        20.0          3  ...               0
# 4       1992          1992         0.0          4  ...               0
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# 0               0             0             0            1
# ...

# %%
# replace testing 
test_df.value_counts('Fence')
# Out:
# Fence
# 0    1150
# 3     172
# 4      59
# 2      58
# 1       1
# dtype: int64

# %%
test_df['firstflrsf'] = test_df['1stFlrSF']

# %%
test_df['secondflrsf'] = test_df['2ndFlrSF']

# %%
test_df['thirdPorch'] = test_df['3SsnPorch']

# %%
del test_df['3SsnPorch']

# %%
del test_df['2ndFlrSF']

# %%
del test_df['1stFlrSF']

# %%
test_df.to_csv(r'F:/House-Pricing-Predictions/Cleaned_data/test_converted_df.csv', index = False)
