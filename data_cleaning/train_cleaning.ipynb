# %%
import pandas as pd

# %%
csv_file = '../Resources/train.csv'
csv_file
# Out:
# '../Resources/train.csv'

# %%
train_df = pd.read_csv(csv_file)
train_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_df = train_df.loc[(train_df["MSZoning"]=="FV") | (train_df["MSZoning"]=="RH") | (train_df["MSZoning"]=="RL") | (train_df["MSZoning"]=="RP") | (train_df["MSZoning"]=="RM")]

# %%
# get dummies
# MSZoning_dummies = pd.get_dummies(train_df.MSZoning, prefix='MSZoning').iloc[:, 1:]
# MSZoning_dummies.head()

# %%
for col in train_df.columns:
    print(col)
# Out:
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# ...

# %%
# Passing dataframe in to Get dummies for non hierarchical variables 
train_df = pd.get_dummies(train_df, columns=['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope','Neighborhood', 'Condition1', 'Condition2','BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'PavedDrive', 'MiscFeature', 'SaleType', 'SaleCondition'], drop_first=True) 
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea ExterQual  ... SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0        Gd  ...              0              0
# 1          1976         0.0        TA  ...              0              0
# 2          2002       162.0        Gd  ...              0              0
# 3          1970         0.0        TA  ...              0              0
# 4          2000       350.0        Gd  ...              0              0
#
# ...

# %%
train_df.LotFrontage.fillna(0, inplace=True)

# %%
train_df[train_df.LotFrontage.isnull()]
# Out:
# Empty DataFrame
# ...

# %%
train_df["GarageYrBlt"].mean()
# Out:
# 1978.6272793581327

# %%
train_df.GarageYrBlt.fillna(1979, inplace=True)

# %% [markdown]
# # Hirachial variables
# ExterQual
# ExterCond
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# HeatingQC
# KitchenQual
# Functional
# FireplaceQu
# GarageFinish
# GarageQual
# GarageCond
# Fence

# %%
train_df.value_counts('ExterQual')
# Out:
# ExterQual
# TA    899
# Gd    488
# Ex     52
# Fa     11
# dtype: int64

# %%
train_df.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1450 entries, 0 to 1459
# Data columns (total 204 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     1450 non-null   int64
#  1   MSSubClass             1450 non-null   int64
#  2   LotFrontage            1450 non-null   float64
#  3   LotArea                1450 non-null   int64
#  4   OverallQual            1450 non-null   int64
#  5   OverallCond            1450 non-null   int64
#  6   YearBuilt              1450 non-null   int64
#  7   YearRemodAdd           1450 non-null   int64
#  8   MasVnrArea             1442 non-null   float64
#  9   ExterQual              1450 non-null   object
#  10  ExterCond              1450 non-null   object
#  11  BsmtQual               1413 non-null   object
#  12  BsmtCond               1413 non-null   object
#  13  BsmtExposure           1412 non-null   object
# ...

# %%
train_df.isnull().sum()
# Out:
# Id                       0
# MSSubClass               0
# LotFrontage              0
# LotArea                  0
# OverallQual              0
#                         ..
# SaleCondition_AdjLand    0
# SaleCondition_Alloca     0
# SaleCondition_Family     0
# SaleCondition_Normal     0
# SaleCondition_Partial    0
# Length: 204, dtype: int64

# %%
train_df.ExterQual.value_counts(dropna=False)
# Out:
# TA    899
# Gd    488
# Ex     52
# Fa     11
# Name: ExterQual, dtype: int64

# %%
train_df.ExterQual.fillna(0, inplace=True)

# %%
# formatting  ['ExterQual'] to Hirachial value 
train_df['ExterQual'] = train_df['ExterQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ... SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0          4  ...              0              0
# 1          1976         0.0          3  ...              0              0
# 2          2002       162.0          4  ...              0              0
# 3          1970         0.0          3  ...              0              0
# 4          2000       350.0          4  ...              0              0
#
# ...

# %%
# replace testing 
train_df.value_counts('ExterQual')
# Out:
# ExterQual
# 3    899
# 4    488
# 5     52
# 2     11
# dtype: int64

# %%
train_df.ExterCond.value_counts(dropna=False)
# Out:
# TA    1275
# Gd     145
# Fa      26
# Ex       3
# Po       1
# Name: ExterCond, dtype: int64

# %%
train_df.ExterCond.fillna(0, inplace=True)

# %%
# formatting  ['ExterCond'] to Hirachial value 
train_df['ExterCond'] = train_df['ExterCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI SaleType_ConLw  \
# 0          2003       196.0          4  ...               0              0
# 1          1976         0.0          3  ...               0              0
# 2          2002       162.0          4  ...               0              0
# 3          1970         0.0          3  ...               0              0
# 4          2000       350.0          4  ...               0              0
#
# ...

# %%
# replace testing 
train_df.value_counts('ExterCond')
# Out:
# ExterCond
# 3    1275
# 4     145
# 2      26
# 5       3
# 1       1
# dtype: int64

# %%
train_df.BsmtQual.value_counts(dropna=False)
# Out:
# TA     639
# Gd     618
# Ex     121
# NaN     37
# Fa      35
# Name: BsmtQual, dtype: int64

# %%
train_df.BsmtQual.fillna(0, inplace=True)

# %%
train_df.BsmtQual.value_counts()
# Out:
# TA    639
# Gd    618
# Ex    121
# 0      37
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
# train_df.loc[train_df.BsmtQual.isnull()]['BsmtQual']

# %%
# formatting  ['BsmtQual'] to Hirachial value 
train_df['BsmtQual'] = train_df['BsmtQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtQual')
# Out:
# BsmtQual
# 3    639
# 4    618
# 5    121
# 0     37
# 2     35
# dtype: int64

# %%
train_df.BsmtCond.value_counts(dropna=False)
# Out:
# TA     1303
# Gd       65
# Fa       43
# NaN      37
# Po        2
# Name: BsmtCond, dtype: int64

# %%
train_df.BsmtCond.fillna(0, inplace=True)

# %%
#train_df.loc[train_df.BsmtCond.isnull()]['BsmtCond']

# %%
# formatting  ['BsmtCond'] to Hirachial value 
train_df['BsmtCond'] = train_df['BsmtCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtCond')
# Out:
# BsmtCond
# 3    1303
# 4      65
# 2      43
# 0      37
# 1       2
# dtype: int64

# %%
train_df.BsmtExposure.value_counts(dropna=False)
# Out:
# No     947
# Av     219
# Gd     134
# Mn     112
# NaN     38
# Name: BsmtExposure, dtype: int64

# %%
train_df.BsmtExposure.fillna(0, inplace=True)

# %%
# formatting  ['BsmtExposure'] to Hirachial value 
train_df['BsmtExposure'] = train_df['BsmtExposure'].replace({'Gd': 4, 'Av': 3, 'Mn': 2, 'No': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtExposure')
# Out:
# BsmtExposure
# 1    947
# 3    219
# 4    134
# 2    112
# 0     38
# dtype: int64

# %%
train_df.BsmtFinType1.value_counts(dropna=False)
# Out:
# Unf    424
# GLQ    418
# ALQ    220
# BLQ    147
# Rec    130
# LwQ     74
# NaN     37
# Name: BsmtFinType1, dtype: int64

# %%
train_df.BsmtFinType1.fillna(0, inplace=True)

# %%
# formatting  ['BsmtFinType1'] to Hirachial value 
train_df['BsmtFinType1'] = train_df['BsmtFinType1'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtFinType1')
# Out:
# BsmtFinType1
# 1    424
# 6    418
# 5    220
# 4    147
# 3    130
# 2     74
# 0     37
# dtype: int64

# %%
train_df.BsmtFinType2.value_counts(dropna=False)
# Out:
# Unf    1246
# Rec      54
# LwQ      46
# NaN      38
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64

# %%
train_df.BsmtFinType2.fillna(0, inplace=True)

# %%
# formatting  ['BsmtFinType2'] to Hirachial value 
train_df['BsmtFinType2'] = train_df['BsmtFinType2'].replace({'GLQ': 6, 'ALQ': 5, 'BLQ': 4, 'Rec': 3, 'LwQ':2, 'Unf': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('BsmtFinType2')
# Out:
# BsmtFinType2
# 1    1246
# 3      54
# 2      46
# 0      38
# 4      33
# 5      19
# 6      14
# dtype: int64

# %%
train_df.HeatingQC.value_counts(dropna=False)
# Out:
# Ex    740
# TA    421
# Gd    239
# Fa     49
# Po      1
# Name: HeatingQC, dtype: int64

# %%
train_df.HeatingQC.fillna(0, inplace=True)

# %%
# formatting  ['HeatingQC'] to Hirachial value 
train_df['HeatingQC'] = train_df['HeatingQC'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('HeatingQC')
# Out:
# HeatingQC
# 5    740
# 3    421
# 4    239
# 2     49
# 1      1
# dtype: int64

# %%
train_df.KitchenQual.value_counts(dropna=False)
# Out:
# TA    727
# Gd    586
# Ex    100
# Fa     37
# Name: KitchenQual, dtype: int64

# %%
train_df.KitchenQual.fillna(0, inplace=True)

# %%
# formatting  ['KitchenQual'] to Hirachial value 
train_df['KitchenQual'] = train_df['KitchenQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('KitchenQual')
# Out:
# KitchenQual
# 3    727
# 4    586
# 5    100
# 2     37
# dtype: int64

# %%
train_df.Functional.value_counts(dropna=False)
# Out:
# Typ     1350
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: Functional, dtype: int64

# %%
train_df.Functional.fillna(0, inplace=True)

# %%
# formatting  ['Functional'] to Hirachial value 
train_df['Functional'] = train_df['Functional'].replace({'Typ': 8, 'Min1': 7, 'Min2': 6, 'Mod': 5, 'Maj1': 4, 'Maj2': 3 , 'Sev': 2, 'Sal': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('Functional')
# Out:
# Functional
# 8    1350
# 6      34
# 7      31
# 5      15
# 4      14
# 3       5
# 2       1
# dtype: int64

# %%
train_df.FireplaceQu.value_counts(dropna=False)
# Out:
# NaN    681
# Gd     379
# TA     313
# Fa      33
# Ex      24
# Po      20
# Name: FireplaceQu, dtype: int64

# %%
train_df.FireplaceQu.fillna(0, inplace=True)

# %%
# formatting  ['FireplaceQu'] to Hirachial value 
train_df['FireplaceQu'] = train_df['FireplaceQu'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('FireplaceQu')
# Out:
# FireplaceQu
# 0    681
# 4    379
# 3    313
# 2     33
# 5     24
# 1     20
# dtype: int64

# %%
train_df.GarageFinish.value_counts(dropna=False)
# Out:
# Unf    600
# RFn    419
# Fin    352
# NaN     79
# Name: GarageFinish, dtype: int64

# %%
train_df.GarageFinish.fillna(0, inplace=True)

# %%
# formatting  ['GarageFinish'] to Hirachial value 
train_df['GarageFinish'] = train_df['GarageFinish'].replace({'Fin': 3, 'RFn': 2, 'Unf': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageFinish')
# Out:
# GarageFinish
# 1    600
# 2    419
# 3    352
# 0     79
# dtype: int64

# %%
train_df.GarageQual.value_counts(dropna=False)
# Out:
# TA     1303
# NaN      79
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64

# %%
train_df.GarageQual.fillna(0, inplace=True)

# %%
# formatting  ['GarageQual'] to Hirachial value 
train_df['GarageQual'] = train_df['GarageQual'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageQual')
# Out:
# GarageQual
# 3    1303
# 0      79
# 2      48
# 4      14
# 5       3
# 1       3
# dtype: int64

# %%
train_df.GarageCond.value_counts(dropna=False)
# Out:
# TA     1319
# NaN      79
# Fa       34
# Gd        9
# Po        7
# Ex        2
# Name: GarageCond, dtype: int64

# %%
train_df.GarageCond.fillna(0, inplace=True)

# %%
# formatting  ['GarageCond'] to Hirachial value 
train_df['GarageCond'] = train_df['GarageCond'].replace({'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po':1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('GarageCond')
# Out:
# GarageCond
# 3    1319
# 0      79
# 2      34
# 4       9
# 1       7
# 5       2
# dtype: int64

# %%
train_df.PoolQC.value_counts(dropna=False)
# Out:
# NaN    1443
# Gd        3
# Ex        2
# Fa        2
# Name: PoolQC, dtype: int64

# %%
train_df.PoolQC.fillna(0, inplace=True)

# %%
# formatting  ['PoolQC'] to Hirachial value 
train_df['PoolQC'] = train_df['PoolQC'].replace({'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'NaN': 0})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('PoolQC')
# Out:
# PoolQC
# 0    1443
# 3       3
# 4       2
# 1       2
# dtype: int64

# %%
train_df.Fence.value_counts(dropna=False)
# Out:
# NaN      1172
# MnPrv     155
# GdPrv      59
# GdWo       53
# MnWw       11
# Name: Fence, dtype: int64

# %%
train_df.Fence.fillna(0, inplace=True)

# %%
# formatting  ['Fence'] to Hirachial value 
train_df['Fence'] = train_df['Fence'].replace({'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1})
train_df.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLI  SaleType_ConLw  \
# 0          2003       196.0          4  ...               0               0
# 1          1976         0.0          3  ...               0               0
# 2          2002       162.0          4  ...               0               0
# 3          1970         0.0          3  ...               0               0
# 4          2000       350.0          4  ...               0               0
#
# ...

# %%
# replace testing 
train_df.value_counts('Fence')
# Out:
# Fence
# 0    1172
# 3     155
# 4      59
# 2      53
# 1      11
# dtype: int64

# %%
train_df['firstflrsf'] = train_df['1stFlrSF']

# %%
train_df['secondflrsf'] = train_df['2ndFlrSF']

# %%
train_df['thirdPorch'] = train_df['3SsnPorch']

# %%
del train_df['3SsnPorch']

# %%
del train_df['2ndFlrSF']

# %%
del train_df['1stFlrSF']

# %%
train_df.to_csv(r'F:/House-Pricing-Predictions/Cleaned_data/train_converted_df.csv', index = False)
